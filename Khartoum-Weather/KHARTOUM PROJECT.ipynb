# %%
# Import packages

import numpy as np
import pandas as pd
from statistics import *
import matplotlib.pylab as plt
# %matplotlib inline 
from matplotlib.pylab import rcParams
rcParams ['figure.figsize']= 10,6
import seaborn as sns

sns.set()

# %%
df1 =pd.read_csv('temp_data.csv') 
df1.head()
# Out:
#         Day  WHF  ABH  PSD  DNG  KRM  ATB  SHN  KHA
# 0  1/1/2018   37   38   38   38   38   36   40   40
# 1  1/2/2018   35   37   37   39   39   40   40   37
# 2  1/3/2018   37   36   35   35   39   35   37   37
# 3  1/4/2018   40   39   38   39   39   35   36   39
# 4  1/5/2018   40   36   36   39   37   37   35   40

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1613 entries, 0 to 1612
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Day     1613 non-null   object
#  1   WHF     1613 non-null   int64
#  2   ABH     1613 non-null   int64
#  3   PSD     1613 non-null   int64
#  4   DNG     1613 non-null   int64
#  5   KRM     1613 non-null   int64
#  6   ATB     1613 non-null   int64
#  7   SHN     1613 non-null   int64
#  8   KHA     1613 non-null   int64
# dtypes: int64(8), object(1)
# memory usage: 113.5+ KB

# %%
df1.describe()
# Out:
#                WHF          ABH          PSD          DNG          KRM  \
# count  1613.000000  1613.000000  1613.000000  1613.000000  1613.000000
# mean     33.909485    33.608184    33.885307    33.931184    33.923125
# std       6.830579     6.908493     6.835073     7.063140     7.016396
# min      20.000000    20.000000    20.000000    20.000000    20.000000
# 25%      29.000000    28.000000    29.000000    28.000000    28.000000
# 50%      35.000000    35.000000    35.000000    35.000000    35.000000
# 75%      39.000000    39.000000    39.000000    39.000000    39.000000
# max      45.000000    45.000000    45.000000    45.000000    45.000000
#
#                ATB          SHN          KHA
# count  1613.000000  1613.000000  1613.000000
# mean     34.076875    33.768134    33.487291
# std       7.014539     6.990568     7.036461
# min      20.000000    20.000000    20.000000
# 25%      29.000000    28.000000    28.000000
# 50%      36.000000    36.000000    35.000000
# ...

# %%
df1.head()
# Out:
#         Day  WHF  ABH  PSD  DNG  KRM  ATB  SHN  KHA
# 0  1/1/2018   37   38   38   38   38   36   40   40
# 1  1/2/2018   35   37   37   39   39   40   40   37
# 2  1/3/2018   37   36   35   35   39   35   37   37
# 3  1/4/2018   40   39   38   39   39   35   36   39
# 4  1/5/2018   40   36   36   39   37   37   35   40

# %%
df1.tail()
# Out:
#             Day  WHF  ABH  PSD  DNG  KRM  ATB  SHN  KHA
# 1608  5/28/2022   31   32   33   40   43   45   43   22
# 1609  5/29/2022   45   42   41   33   39   29   43   35
# 1610  5/30/2022   29   41   44   31   41   21   26   43
# 1611  5/31/2022   33   27   21   30   32   39   37   41
# 1612   6/1/2022   35   35   38   27   41   23   25   38

# %%
df1.isna().sum()
df1['KHA'].fillna(int(df1['KHA'].mean()), inplace=True)

# %%
print(df.shape)
# Out:
# (1613, 8)

# %%
df1['Day'] = pd.to_datetime(df1['Day'],infer_datetime_format=True)
#df['Day'] = pd.to_datetime(df['Day'])
print(df1.head())
#, format='%Y-%mm-%dddd-'
# Out:
#          Day  WHF  ABH  PSD  DNG  KRM  ATB  SHN  KHA
# 0 2018-01-01   37   38   38   38   38   36   40   40
# 1 2018-01-02   35   37   37   39   39   40   40   37
# 2 2018-01-03   37   36   35   35   39   35   37   37
# 3 2018-01-04   40   39   38   39   39   35   36   39
# 4 2018-01-05   40   36   36   39   37   37   35   40

# %%
df = df1.set_index(['Day'])
print(df.head())
# Out:
#             WHF  ABH  PSD  DNG  KRM  ATB  SHN  KHA
# Day
# 2018-01-01   37   38   38   38   38   36   40   40
# 2018-01-02   35   37   37   39   39   40   40   37
# 2018-01-03   37   36   35   35   39   35   37   37
# 2018-01-04   40   39   38   39   39   35   36   39
# 2018-01-05   40   36   36   39   37   37   35   40

# %%
print(df.tail())
# Out:
#             WHF  ABH  PSD  DNG  KRM  ATB  SHN  KHA
# Day
# 2022-05-28   31   32   33   40   43   45   43   22
# 2022-05-29   45   42   41   33   39   29   43   35
# 2022-05-30   29   41   44   31   41   21   26   43
# 2022-05-31   33   27   21   30   32   39   37   41
# 2022-06-01   35   35   38   27   41   23   25   38

# %%
#plotting all data 
df.plot(figsize=(7,4), linewidth=1, fontsize=10)
plt.xlabel('Year', fontsize=10);

# %%
#corr
df.corr()
# Out:
#           WHF       ABH       PSD       DNG       KRM       ATB       SHN  \
# WHF  1.000000  0.079031  0.075966  0.097747  0.091665  0.077182  0.089826
# ABH  0.079031  1.000000  0.090260  0.103606  0.065262  0.064756  0.079004
# PSD  0.075966  0.090260  1.000000  0.104009  0.068386  0.100705  0.087378
# DNG  0.097747  0.103606  0.104009  1.000000  0.048812  0.089456  0.115478
# KRM  0.091665  0.065262  0.068386  0.048812  1.000000  0.075999  0.128187
# ATB  0.077182  0.064756  0.100705  0.089456  0.075999  1.000000  0.098560
# SHN  0.089826  0.079004  0.087378  0.115478  0.128187  0.098560  1.000000
# KHA  0.123353  0.137133  0.091658  0.080547  0.079279  0.029983  0.085371
#
#           KHA
# WHF  0.123353
# ABH  0.137133
# PSD  0.091658
# DNG  0.080547
# KRM  0.079279
# ATB  0.029983
# SHN  0.085371
# KHA  1.000000

# %%
#diff
df.diff()
# Out:
#              WHF   ABH   PSD   DNG  KRM   ATB   SHN   KHA
# Day
# 2018-01-01   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN
# 2018-01-02  -2.0  -1.0  -1.0   1.0  1.0   4.0   0.0  -3.0
# 2018-01-03   2.0  -1.0  -2.0  -4.0  0.0  -5.0  -3.0   0.0
# 2018-01-04   3.0   3.0   3.0   4.0  0.0   0.0  -1.0   2.0
# 2018-01-05   0.0  -3.0  -2.0   0.0 -2.0   2.0  -1.0   1.0
# ...          ...   ...   ...   ...  ...   ...   ...   ...
# 2022-05-28 -14.0   3.0  11.0  16.0  7.0  12.0   9.0  -7.0
# 2022-05-29  14.0  10.0   8.0  -7.0 -4.0 -16.0   0.0  13.0
# 2022-05-30 -16.0  -1.0   3.0  -2.0  2.0  -8.0 -17.0   8.0
# 2022-05-31   4.0 -14.0 -23.0  -1.0 -9.0  18.0  11.0  -2.0
# 2022-06-01   2.0   8.0  17.0  -3.0  9.0 -16.0 -12.0  -3.0
#
# [1613 rows x 8 columns]

# %%
#corr diff 
df.diff().corr()
# Out:
#           WHF       ABH       PSD       DNG       KRM       ATB       SHN  \
# WHF  1.000000  0.005968 -0.007520  0.021846  0.001194  0.058213 -0.002610
# ABH  0.005968  1.000000  0.021173  0.010106 -0.054178  0.007191 -0.005407
# PSD -0.007520  0.021173  1.000000  0.002012 -0.013075  0.036820 -0.030841
# DNG  0.021846  0.010106  0.002012  1.000000 -0.016149  0.013570  0.035756
# KRM  0.001194 -0.054178 -0.013075 -0.016149  1.000000  0.020204  0.049951
# ATB  0.058213  0.007191  0.036820  0.013570  0.020204  1.000000  0.016647
# SHN -0.002610 -0.005407 -0.030841  0.035756  0.049951  0.016647  1.000000
# KHA  0.040963  0.034758  0.011524 -0.011953 -0.029742 -0.043055 -0.023635
#
#           KHA
# WHF  0.040963
# ABH  0.034758
# PSD  0.011524
# DNG -0.011953
# KRM -0.029742
# ATB -0.043055
# SHN -0.023635
# KHA  1.000000

# %%
#KHA
df[['KHA']].plot(figsize=(7,4), linewidth=1, fontsize=10)
plt.xlabel('Year', fontsize=10);

# %%
from scipy import*

# %%
KHAdata= df[['KHA']]

# %%
KHAdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1613 entries, 2018-01-01 to 2022-06-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   KHA     1613 non-null   int64
# dtypes: int64(1)
# memory usage: 25.2 KB

# %%
KHAdata.head()
# Out:
#             KHA
# Day
# 2018-01-01   40
# 2018-01-02   37
# 2018-01-03   37
# 2018-01-04   39
# 2018-01-05   40

# %%
KHAdata.plot()

# %%
rolemean = KHAdata['KHA'].rolling(window=12).mean ()
rolestd   = KHAdata['KHA'].rolling(window=12).std ()
print (mean,std)
# Out:
# <function mean at 0x00000180B66AC4C8> <function std at 0x00000180B66AF9D8>

# %%
#plot rolling of Kha
orignal =plt.plot(KHAdata, color ='blue', label ='Orginal')
mean    = plt.plot(rolemean ,color = 'red',label ='Rolling Mean')
std     = plt.plot(rolestd ,color = 'black',label ='Rolling std')
plt.legend(loc ='best')
plt.title('Rolling Mean & STD')
plt.show(block=False)

# %%
from statsmodels.tsa.stattools import adfuller
print ('Result of Dickey-Fuller Test:')
dftest=adfuller(KHAdata['KHA'],autolag ='AIC')
dfoutput = pd.Series(dftest [0:4],index=['Test Statistic','p-value',
   '#Logs Used', 'Number of Observation used'])
for key ,value in dftest[4].items ():
    dfoutput['Critical Value (%s)'%key]= value
print(dfoutput)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic                  -4.717097
# p-value                          0.000078
# #Logs Used                      20.000000
# Number of Observation used    1592.000000
# Critical Value (1%)             -3.434464
# Critical Value (5%)             -2.863357
# Critical Value (10%)            -2.567737
# dtype: float64

# %%
#estimating trent 

KHA_logScale = np.log(KHAdata)
plt.plot(KHA_logScale)

# %%
KHA_sqrtScale = np.sqrt(KHAdata)
plt.plot(KHA_sqrtScale )

# %%
KHA_cbrtScale = np.cbrt(KHAdata)
plt.plot(KHA_cbrtScale )

# %%
from statsmodels.tsa.stattools import adfuller 
def test_sataionarity (timeseries):
    #determing rolling satatistics 
    movingAverage = timeseries.rolling(window =12).mean()
    movingSTD =timeseries.rolling(window=12).std()
    #plot rolling of statistics
    orignal =plt.plot(timeseries, color ='blue', label ='Orginal')
    mean    = plt.plot(movingAverage ,color = 'red',label ='Rolling Mean')
    std     = plt.plot(movingSTD ,color = 'black',label ='Rolling std')
    plt.legend(loc ='best')
    plt.title('Rolling Mean & STD')
    plt.show(block=False)
    
    print ('Result of Dickey-Fuller Test:')
    dftest=adfuller(timeseries['KHA'],autolag ='AIC')
    dfoutput = pd.Series(dftest [0:4],index=['Test Statistic','p-value',
    '#Logs Used', 'Number of Observation used'])
    for key ,value in dftest[4].items ():
        dfoutput['Critical Value (%s)'%key]= value
    print(dfoutput)

# %%
test_sataionarity(KHAdata)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic                  -4.717097
# p-value                          0.000078
# #Logs Used                      20.000000
# Number of Observation used    1592.000000
# Critical Value (1%)             -3.434464
# Critical Value (5%)             -2.863357
# Critical Value (10%)            -2.567737
# dtype: float64

# %%
test_sataionarity(KHA_logScale)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic                  -4.537824
# p-value                          0.000168
# #Logs Used                      20.000000
# Number of Observation used    1592.000000
# Critical Value (1%)             -3.434464
# Critical Value (5%)             -2.863357
# Critical Value (10%)            -2.567737
# dtype: float64

# %%
test_sataionarity(KHA_sqrtScale )
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic                  -4.613682
# p-value                          0.000122
# #Logs Used                      20.000000
# Number of Observation used    1592.000000
# Critical Value (1%)             -3.434464
# Critical Value (5%)             -2.863357
# Critical Value (10%)            -2.567737
# dtype: float64

# %%
test_sataionarity(KHA_cbrtScale)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic                  -4.585383
# p-value                          0.000137
# #Logs Used                      20.000000
# Number of Observation used    1592.000000
# Critical Value (1%)             -3.434464
# Critical Value (5%)             -2.863357
# Critical Value (10%)            -2.567737
# dtype: float64

# %% [markdown]
# # use  different as its seosen i will use 12 different

# %%
datasetDiffshifting = KHAdata-KHAdata.shift(12)

# %%
plt.plot(datasetDiffshifting)

# %%
datasetDiffshifting.dropna(inplace=True)

# %%
datasetDiffshifting.head()
# Out:
#             KHA
# Day
# 2018-01-13 -5.0
# 2018-01-14  1.0
# 2018-01-15  2.0
# 2018-01-16 -4.0
# 2018-01-17 -1.0

# %%
test_sataionarity(datasetDiffshifting )
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic               -1.381039e+01
# p-value                       8.252131e-26
# #Logs Used                    2.300000e+01
# Number of Observation used    1.577000e+03
# Critical Value (1%)          -3.434503e+00
# Critical Value (5%)          -2.863374e+00
# Critical Value (10%)         -2.567747e+00
# dtype: float64

# %%
from statsmodels.tsa.stattools import acf,pacf 
lag_acf =acf(datasetDiffshifting,nlags=20)
lag_pacf=pacf(datasetDiffshifting,nlags =20,method ='ols')

#plot ACF:
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0 ,linestyle ='--', color= 'gray')
plt.axhline(y=1.96/np.sqrt(len(datasetDiffshifting)) ,linestyle ='--', color= 'gray')
plt.axhline(y=-1.96/np.sqrt(len(datasetDiffshifting)) ,linestyle ='--', color= 'gray')
plt.title('Autocorrleation')


#plot PACF
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0 ,linestyle ='--', color= 'gray')
plt.axhline(y=1.96/np.sqrt(len(datasetDiffshifting)) ,linestyle ='--', color= 'gray')
plt.axhline(y=-1.96/np.sqrt(len(datasetDiffshifting)) ,linestyle ='--', color= 'gray')
plt.title('partial Autocorrleation')
 
plt.tight_layout()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
acf= plot_acf(datasetDiffshifting.dropna())

# %%
pacf= plot_pacf(datasetDiffshifting.dropna())

# %%
datasetDiffshifting.head()
# Out:
#             KHA
# Day
# 2018-01-13 -5.0
# 2018-01-14  1.0
# 2018-01-15  2.0
# 2018-01-16 -4.0
# 2018-01-17 -1.0

# %%
datasetDiffshifting.tail()
# Out:
#              KHA
# Day
# 2022-05-28 -17.0
# 2022-05-29   9.0
# 2022-05-30  17.0
# 2022-05-31  14.0
# 2022-06-01  -4.0

# %%
#auto Arima

# %%
from pmdarima import auto_arima

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
stepwise_fit = auto_arima(datasetDiffshifting['KHA'],trace = True,suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=11759.661, Time=2.60 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=11853.476, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=11853.867, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=11853.957, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=11851.483, Time=0.02 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=11856.450, Time=0.59 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=11856.426, Time=0.22 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=11860.435, Time=0.59 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=2.34 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=11855.150, Time=0.22 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=11858.451, Time=0.39 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=11858.433, Time=0.35 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=3.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=11856.375, Time=0.46 sec
# ...

# %%
#split data

# %%
print (datasetDiffshifting.shape)
# Out:
# (1601, 1)

# %%
train=datasetDiffshifting.iloc[:-350]
test= datasetDiffshifting.iloc[-350:]
print(train.shape,test.shape)
# Out:
# (1251, 1) (350, 1)

# %%
#train model

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model=ARIMA(train['KHA'],order=(2,0,2))
model=model.fit()
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-421-55daeba0ade9> in <module>
# ----> 1 model=ARIMA(train['KHA'],order=(2,0,2))
#       2 model=model.fit()
#       3 model.summary()
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# ...

# %%
start= len(train)
end=len(train)+len(test)-1
pred = model.predict(start=start,end=end,typ='levels')

#pred.index=datasetDiffshifting.index[start:end+1]
print(pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-422-5f90cf967453> in <module>
#       1 start= len(train)
#       2 end=len(train)+len(test)-1
# ----> 3 pred = model.predict(start=start,end=end,typ='levels')
#       4
#       5 #pred.index=datasetDiffshifting.index[start:end+1]
#
# NameError: name 'model' is not defined

# %%
pred.plot(legend=True)
test['KHA'].plot(legend=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-423-c24080bd1a86> in <module>
# ----> 1 pred.plot(legend=True)
#       2 test['KHA'].plot(legend=True)
#
# NameError: name 'pred' is not defined

# %% [markdown]
# # SARIMAX

# %%
import statsmodels.api as sm

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_sarimax = sm.tsa.statespace.SARIMAX(datasetDiffshifting['KHA'],order =(2,0,2),seasonal_order =(0,0,0,12))

# %%
modelsarimax=model_sarimax.fit()

# %%
modelsarimax.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                    KHA   No. Observations:                 1601
# Model:               SARIMAX(2, 0, 2)   Log Likelihood               -5923.188
# Date:                Mon, 08 Aug 2022   AIC                          11856.375
# Time:                        20:27:32   BIC                          11883.267
# Sample:                    01-13-2018   HQIC                         11866.361
#                          - 06-01-2022
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2555      1.149     -0.222      0.824      -2.508       1.997
# ar.L2         -0.1729      0.720     -0.240      0.810      -1.585       1.239
# ma.L1          0.2236      1.146      0.195      0.845      -2.022       2.470
# ...

# %%
datasetDiffshifting['forcast']= modelsarimax.predict(start=150,end=1600, dynamic=True)
datasetDiffshifting[['KHA','forcast']].plot(figsize= (12,8))

# %%
from pandas.tseries.offsets import DateOffset

# %%
future_dates=[datasetDiffshifting.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
#datasetDiffshifting.head()

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=datasetDiffshifting.columns)

# %%
future_datest_df.tail()
# Out:
#             KHA forcast
# 2024-01-01  NaN     NaN
# 2024-02-01  NaN     NaN
# 2024-03-01  NaN     NaN
# 2024-04-01  NaN     NaN
# 2024-05-01  NaN     NaN

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=datasetDiffshifting.columns)

# %%
future_datest_df.tail()
# Out:
#             KHA forcast
# 2024-01-01  NaN     NaN
# 2024-02-01  NaN     NaN
# 2024-03-01  NaN     NaN
# 2024-04-01  NaN     NaN
# 2024-05-01  NaN     NaN

# %%
future_df=pd.concat([datasetDiffshifting,future_datest_df])

# %%
future_df['forcast'] = modelsarimax.predict(start = 1500, end = 1800, dynamic= True)

# %%
future_df[['KHA', 'forcast']].plot(figsize=(12, 8))

# %%
future_df.head()
# Out:
#             KHA  forcast
# 2018-01-13 -5.0      NaN
# 2018-01-14  1.0      NaN
# 2018-01-15  2.0      NaN
# 2018-01-16 -4.0      NaN
# 2018-01-17 -1.0      NaN
