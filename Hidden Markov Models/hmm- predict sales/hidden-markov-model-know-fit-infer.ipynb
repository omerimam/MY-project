# %% [markdown]
# <div style="background-color:#F0E3D2; color:#19180F; font-size:15px; font-family:Verdana; padding:10px; border: 2px solid #19180F; border-radius:10px">
# 📌 Installing hmmlearn </div>

# %%
#!pip install hmmlearn

# %% [markdown]
# <div style="background-color:#F0E3D2; color:#19180F; font-size:15px; font-family:Verdana; padding:10px; border: 2px solid #19180F; border-radius:10px">
# 📌 Importing relevant modules </div>

# %%
import pandas as pd
import numpy as np
from hmmlearn import hmm

# %% [markdown]
# <div style="background-color:#F0E3D2; color:#19180F; font-size:15px; font-family:Verdana; padding:10px; border: 2px solid #19180F; border-radius:10px">
# 📌 Loading the dataframe </div>

# %%
sales_train = pd.read_csv('sales_train.csv')
sales_train
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %% [markdown]
# <div style="background-color:#F0E3D2; color:#19180F; font-size:15px; font-family:Verdana; padding:10px; border: 2px solid #19180F; border-radius:10px">
# 📌 Extracting the features </div>

# %%
sales_train= sales_train.drop(['date_block_num','item_cnt_day'],axis=1)

# %%
X_train = sales_train[['shop_id', 'item_id']].values
X_train
# Out:
# array([[   59, 22154],
#        [   25,  2552],
#        [   25,  2552],
#        ...,
#        [   25,  7459],
#        [   25,  7440],
#        [   25,  7460]], dtype=int64)

# %% [markdown]
# <div style="background-color:#F0E3D2; color:#19180F; font-size:15px; font-family:Verdana; padding:10px; border: 2px solid #19180F; border-radius:10px">
# 📌 Initializing and training the HMM </div>

# %%
n_hidden_states = 5  # Number of hidden states in the HMM
model = hmm.MultinomialHMM(n_components=n_hidden_states, n_iter=100,verbose=True)
model.fit(X_train)
# Out:
# MultinomialHMM has undergone major changes. The previous version was implementing a CategoricalHMM (a special case of MultinomialHMM). This new implementation follows the standard definition for a Multinomial distribution (e.g. as in https://en.wikipedia.org/wiki/Multinomial_distribution). See these issues for details:
# https://github.com/hmmlearn/hmmlearn/issues/335
# https://github.com/hmmlearn/hmmlearn/issues/340
#          1 -12935101554.91417122             +nan
#          2 -44626461.78835510 +12890475093.12581635
#          3 -42018730.97103351 +2607730.81732160
#          4 -35480877.58672379 +6537853.38430972
#          5 -28980419.26454787 +6500458.32217592
#          6 -25251884.09502894 +3728535.16951893
#          7 -23073113.86317565 +2178770.23185330
#          8 -21536541.36570138 +1536572.49747426
#          9 -20251413.07537027 +1285128.29033111
#         10 -19202822.82530198 +1048590.25006830
#         11 -18420115.82044277 +782707.00485921
#         12 -17767952.38137478 +652163.43906799
#         13 -17214523.83902559 +553428.54234920
#         14 -16675634.88271922 +538888.95630637
#         15 -16219896.40914766 +455738.47357156
#         16 -15809560.50680152 +410335.90234614
#         17 -15407355.77499324 +402204.73180828
#         18 -15049258.22027790 +358097.55471534
#         19 -14711528.91021289 +337729.31006501
#         20 -14401050.09057171 +310478.81964118
#         21 -14102206.10929490 +298843.98127682
#         22 -13813635.89681276 +288570.21248214
#         23 -13576589.66307366 +237046.23373910
#         24 -13405375.82649409 +171213.83657956
#         25 -13297125.83395409 +108249.99254000
#         26 -13218457.02159180  +78668.81236229
#         27 -13166810.44848586  +51646.57310594
#         28 -13132814.62006312  +33995.82842274
#         34 -13042567.76306998   +6681.43663416
#         35 -13038586.94516782   +3980.81790216
#         36 -13036079.77793193   +2507.16723590
#         37 -13034187.64748932   +1892.13044261
#         38 -13032706.74248805   +1480.90500127
#         39 -13031464.43038037   +1242.31210768
#         40 -13030254.88261112   +1209.54776925
#         41 -13029095.64955866   +1159.23305246
#         42 -13028025.59818152   +1070.05137714
#         43 -13026950.97674076   +1074.62144076
#         44 -13025919.34095499   +1031.63578577
#         45 -13025109.46958378    +809.87137121
#         46 -13024467.30492052    +642.16466326
#         47 -13023750.26705769    +717.03786283
#         48 -13022716.74326776   +1033.52378993
#         49 -13017983.22808079   +4733.51518697
#         50 -12987630.96837629  +30352.25970450
#         51 -12965789.65143790  +21841.31693839
#         52 -12951911.93644626  +13877.71499164
#         53 -12946103.49199591   +5808.44445035
#         54 -12943028.72671963   +3074.76527628
#         55 -12933460.43917862   +9568.28754101
#         56 -12923363.63744208  +10096.80173654
#         57 -12910507.22947177  +12856.40797031
#         58 -12882394.49968586  +28112.72978591
#         59 -12843755.16669740  +38639.33298845
#         60 -12817657.47631449  +26097.69038291
#         61 -12795907.30321881  +21750.17309568
#         62 -12772750.47837937  +23156.82483944
#         63 -12743378.20222015  +29372.27615922
#         64 -12717475.44234357  +25902.75987658
#         65 -12702205.70590733  +15269.73643625
#         66 -12690452.04175612  +11753.66415121
#         67 -12673163.70038640  +17288.34136972
#         68 -12645809.29218892  +27354.40819748
#         69 -12617044.96290615  +28764.32928277
#         70 -12593530.89323806  +23514.06966809
#         71 -12578362.82194046  +15168.07129760
#         72 -12566328.09347240  +12034.72846805
#         73 -12555228.25394712  +11099.83952529
#         74 -12546714.17687595   +8514.07707117
#         75 -12539703.53881498   +7010.63806097
#         76 -12533089.17561040   +6614.36320459
#         77 -12527744.03919351   +5345.13641689
#         78 -12523907.55129671   +3836.48789680
#         79 -12520980.73753185   +2926.81376486
#         80 -12518474.83340784   +2505.90412401
#         81 -12516100.63462229   +2374.19878555
#         82 -12513721.29118637   +2379.34343592
#         83 -12511519.94754113   +2201.34364523
#         84 -12509565.27257723   +1954.67496391
#         85 -12507885.50294176   +1679.76963546
#         86 -12506634.47360742   +1251.02933435
#         87 -12505693.17975407    +941.29385334
#         88 -12504986.31460327    +706.86515080
#         89 -12504414.05019898    +572.26440430
#         90 -12503909.78293284    +504.26726614
#         91 -12503455.76250396    +454.02042888
#         92 -12503037.94908470    +417.81341925
#         93 -12502636.03844891    +401.91063580
#         94 -12502208.66280725    +427.37564166
#         95 -12501724.14276729    +484.52003996
#         96 -12501156.73478271    +567.40798458
#         97 -12500520.40545451    +636.32932820
#         98 -12499881.48973651    +638.91571800
#         99 -12499242.27894665    +639.21078986
#        100 -12498578.36872309    +663.91022356
# MultinomialHMM(n_components=5, n_iter=100,
#                n_trials=array([22213,  2577,  2577, ...,  7484,  7465,  7485], dtype=int64),
#                random_state=RandomState(MT19937) at 0x28099FAAA40,
#                verbose=True)

# %% [markdown]
# <div style="background-color:#F0E3D2; color:#19180F; font-size:15px; font-family:Verdana; padding:10px; border: 2px solid #19180F; border-radius:10px">
# 📌 Each line represents the iteration number, the log likelihood value at that iteration, and the change in log likelihood compared to the previous iteration.</div>

# %%
test_data = pd.read_csv('test.csv')
X_test = test_data[['shop_id', 'item_id']].values

# %% [markdown]
# <div style="background-color:#F0E3D2; color:#19180F; font-size:15px; font-family:Verdana; padding:10px; border: 2px solid #19180F; border-radius:10px">
# 📌 Predicting the sales for the test set </div>

# %%
predicted_sales = model.predict(X_test)

# %% [markdown]
# <div style="background-color:#F0E3D2; color:#19180F; font-size:15px; font-family:Verdana; padding:10px; border: 2px solid #19180F; border-radius:10px">
# 📌 Creating submission file </div>

# %%
submission = pd.DataFrame({'ID': test_data['ID'], 'item_cnt_month': predicted_sales})
submission.to_csv('submission.csv', index=False)

# %%
submission
