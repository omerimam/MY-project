# %% [markdown]
#  Explore Business Analytics

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from plotnine import *
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
#pip install plotnine

# %%
#sample = pd.read_csv('SampleSuperstore.csv')
#sample.head(20)

# %%
#sample.shape

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5835 entries, 0 to 5834
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     5835 non-null   object
#  1   Segment       5835 non-null   object
#  2   Country       5835 non-null   object
#  3   City          5835 non-null   object
#  4   Category      5835 non-null   object
#  5   Sub-Category  5835 non-null   object
#  6   Sales         5835 non-null   float64
#  7   Quantity      5835 non-null   int64
#  8   Discount      5835 non-null   float64
#  9   Profit        5835 non-null   float64
#  10  Code          5835 non-null   int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 501.6+ KB

# %%
sample.describe()
# Out:
#               Sales     Quantity     Discount       Profit          Code
# count   5835.000000  5835.000000  5835.000000  5835.000000   5835.000000
# mean     228.543652     3.801371     0.161952    27.161206  55363.481405
# std      572.298005     2.245431     0.208088   202.510204  31894.550189
# min        0.444000     1.000000     0.000000 -3701.892800   1040.000000
# 25%       17.340000     2.000000     0.000000     1.654200  23271.500000
# 50%       54.384000     3.000000     0.200000     8.488800  55901.000000
# 75%      210.760000     5.000000     0.200000    27.958800  90004.000000
# max    13999.960000    14.000000     0.800000  6719.980800  99301.000000

# %%
# Chaecking the dupilication in data
sample.duplicated().sum()
# Out:
# 0

# %%
sample.drop_duplicates(inplace = True)

# %%
sample.head()
# Out:
#         Ship Mode      Segment Country     City         Category Sub-Category  \
# 0    Second Class  Home Office     UAE  Sharjah       Technology    Bookcases
# 1  Standard Class     Consumer     UAE  Sharjah       Technology       Chairs
# 2  Standard Class     Consumer     UAE  Sharjah  Office Supplies       Labels
# 3  Standard Class     Consumer     UAE  Sharjah  Office Supplies       Tables
# 4  Standard Class     Consumer     UAE  Sharjah  Office Supplies      Storage
#
#       Sales  Quantity  Discount    Profit   Code
# 0  1127.976         3       0.2  126.8973  42420
# 1   281.970         3       0.0   78.9516  42420
# 2    69.500         5       0.0   20.1550  90036
# 3   166.440         3       0.0   79.8912  33311
# 4     9.216         4       0.2    3.3408  33311

# %%
sample.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City               8
# Category           3
# Sub-Category      17
# Sales           3966
# Quantity          14
# Discount          12
# Profit          4690
# Code             550
# dtype: int64

# %%
#Correlation Between Variables.
sample.corr()
# Out:
#              Sales  Quantity  Discount    Profit      Code
# Sales     1.000000  0.223818 -0.029926  0.575652 -0.003741
# Quantity  0.223818  1.000000  0.003258  0.079254  0.010092
# Discount -0.029926  0.003258  1.000000 -0.230867  0.002630
# Profit    0.575652  0.079254 -0.230867  1.000000 -0.011435
# Code     -0.003741  0.010092  0.002630 -0.011435  1.000000

# %%
# Covariance of columns
sample.cov()
# Out:
#                   Sales    Quantity   Discount        Profit          Code
# Sales     327525.007065  287.618608  -3.563845  66715.893223 -6.829005e+04
# Quantity     287.618608    5.041959   0.001523     36.038576  7.227593e+02
# Discount      -3.563845    0.001523   0.043301     -9.728696  1.745565e+01
# Profit     66715.893223   36.038576  -9.728696  41010.382608 -7.385780e+04
# Code      -68290.051431  722.759333  17.455649 -73857.798581  1.017262e+09

# %%
sample.head()
# Out:
#         Ship Mode      Segment Country     City         Category Sub-Category  \
# 0    Second Class  Home Office     UAE  Sharjah       Technology    Bookcases
# 1  Standard Class     Consumer     UAE  Sharjah       Technology       Chairs
# 2  Standard Class     Consumer     UAE  Sharjah  Office Supplies       Labels
# 3  Standard Class     Consumer     UAE  Sharjah  Office Supplies       Tables
# 4  Standard Class     Consumer     UAE  Sharjah  Office Supplies      Storage
#
#       Sales  Quantity  Discount    Profit   Code
# 0  1127.976         3       0.2  126.8973  42420
# 1   281.970         3       0.0   78.9516  42420
# 2    69.500         5       0.0   20.1550  90036
# 3   166.440         3       0.0   79.8912  33311
# 4     9.216         4       0.2    3.3408  33311

# %% [markdown]
# # DATA VISUALIZATION

# %%
plt.figure(figsize=(16,8))
plt.bar('Category','Quantity', data=sample)
plt.title('Category vs Quantity	')
plt.xlabel('Catgory')
plt.ylabel('Quantity')
plt.xticks(rotation=45)
plt.show()

# %%
sample.corr()
# Out:
#              Sales  Quantity  Discount    Profit      Code
# Sales     1.000000  0.223818 -0.029926  0.575652 -0.003741
# Quantity  0.223818  1.000000  0.003258  0.079254  0.010092
# Discount -0.029926  0.003258  1.000000 -0.230867  0.002630
# Profit    0.575652  0.079254 -0.230867  1.000000 -0.011435
# Code     -0.003741  0.010092  0.002630 -0.011435  1.000000

# %%
sample.hist(bins=50 ,figsize=(20,15))
plt.show();

# %%
# Count the total repeatable states
sample['City'].value_counts()
# Out:
# Abu-Dahbi         2343
# Dubai             1828
# Sharjah            646
# Al Ain             606
# Ras Al Khaimah     160
# Umm al-Quwain      133
# Ajman               83
# Fujairah            36
# Name: City, dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.countplot(x=sample['City'])
plt.xticks(rotation=90)
plt.title("City")
plt.show()

# %%
Profit_plot = (ggplot(sample, aes(x='Sub-Category', y='Profit', fill='Sub-Category')) + geom_col() + coord_flip()
+ scale_fill_brewer(type='div', palette="Spectral") + theme_classic() + ggtitle('Pie Chart'))

display(Profit_plot)
# Out:
# <ggplot: (-9223371945358372132)>

# %%
sns.set(style="whitegrid")
plt.figure(2, figsize=(20,15))
sns.barplot(x='Sub-Category',y='Profit', data=sample, palette='Spectral')
plt.suptitle('Pie Consumption Patterns in the United Arab emarites ', fontsize=16)
plt.show()

# %%
ggplot(sample, aes(x='Ship Mode', fill = 'Category')) + geom_bar(stat = 'count')
# Out:
# <ggplot: (-9223371945350161372)>

# %%
figsize=(15,10)
sns.pairplot(sample,hue='Sub-Category')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# **Let's explore more about these outliers by using boxplots.**
#
# **Ist we'll check Sales from Every Segments of Whole Data**

# %%
flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(10,5),
                     axis_ticks_length_major=10,axis_ticks_length_minor=5)
(ggplot(sample, aes(x='Sub-Category', fill='Sales')) + geom_bar() + facet_wrap(['Segment']) 
+ flip_xlabels +theme(axis_text_x = element_text(size=12))+ggtitle("Sales From Every Segment Of United States of Whole Data"))
# Out:
# <ggplot: (-9223371945350459840)>

# %% [markdown]
#     From above Graph we can say that "Home Office" segment has less purchased Sub-Categories and in that
#     "Tables","Supplies","Machines","Copiers","Bookcases" has the lowest Sales. "Consumer" has purchased more sub-categories as compared to other segments.

# %%
flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(10,5),
                     axis_ticks_length_major=10,axis_ticks_length_minor=5)
(ggplot(sample, aes(x='Sub-Category', fill='Discount')) + geom_bar() + facet_wrap(['Segment']) 
+ flip_xlabels +theme(axis_text_x = element_text(size=12))+ggtitle("Discount on Categories From Every Segment Of United States of Whole Data"))
# Out:
# <ggplot: (-9223371926999344608)>

# %%
flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=10),figure_size=(10,10),
                     axis_ticks_length_major=50,axis_ticks_length_minor=50)
(ggplot(sample, aes(x='Category', fill='Sales')) + geom_bar() + theme(axis_text_x = element_text(size=10)) 
+ facet_wrap(['City']) + flip_xlabels+ ggtitle("Sales From Every Region Of UAE of Whole Data"))
# Out:
# <ggplot: (-9223371945351100376)>

# %%
plt.figure(figsize=(10,4))
sns.lineplot('Discount','Profit', data=sample , color='y',label='Discount')
plt.legend()
plt.show()

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
fig, ax = plt.subplots(figsize = (10 , 6))
ax.scatter(sample["Sales"] , sample["Profit"])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
ax.set_title('Sales vs Profit')
plt.show()
